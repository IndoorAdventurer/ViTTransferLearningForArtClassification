# %% [markdown]
# Eventually outputs a full subset of the Rijksmuseum dataset, in the form of a csv-file containing image file name and corresponding **TYPE**.
#
# **BIG DISCLAIMER** This project was initially intended for material classification alone, so in terms of variable names, etc, the code often mentions materials, while in reality it can also be type or artist classification.
#
# The Rijksmuseum set is very unbalanced: while there are 400 material classes, 84% falls within the `papier' class. The script below outputs a subset that is much more balanced.
#
# Moreover, a small fraction of the collection has multiple materials, and another fraction has none at all. These are removed from the dataset.

# %%
import os
import random
import pandas as pd
import numpy as np

# %%
# Folder containing all the xml metadata files:
xmlPath = "/home/vincent/Documenten/BachelorsProject/Rijksdata/xml/"

# %%
# Takes the contents of an xml metadata file as input, and outputs
# list of types it specified
def extractType(xmlFile):
    with open(xmlFile) as f:
        xmlStr = f.read()
    
    types = []
    
    matchStr = "<dc:type>"
    begin = xmlStr.find(matchStr)
    while begin != -1:
        end = xmlStr.find("<", begin + len(matchStr))
        types += [xmlStr[begin + len(matchStr):end]]
        begin = xmlStr.find(matchStr, end)
    
    return types

# %%
# Getting all ("image-filename", [type]) pairs
pairs_full = [[file.name.replace(".xml", ".jpg"), extractType(file.path)]
    for file in os.scandir(xmlPath) if file.is_file()]

# %%
# Now only the ones with a single material (so not 0 and not multiple)
pairs = [[pair[0], pair[1][0]] for pair in pairs_full if len(pair[1]) == 1]

# %%
# Creating a histogram containing how often each class occurs:
def createHist(pairs):
    hist = {}
    for pair in pairs:
        if pair[1] in hist:
            hist[pair[1]] += 1
        else:
            hist[pair[1]] = 1

    # Convert to sorted list:
    hist = [[mat, hist[mat]] for mat in hist]
    hist.sort(key = lambda x: x[1], reverse = True)

    return hist

hist = createHist(pairs)

# %%
# Get the gini score: indicates how balanced the dataset is
def gini(arr: np.array):
    arr = np.array(arr)
    A = np.ones((len(arr), len(arr))) * arr
    AT = A.T
    A = np.abs(A - AT)
    numerator = np.sum(A)
    denominator = 2 * len(arr) ** 2 * np.mean(arr)
    return numerator / denominator

# %%
print(f"Number of classes: {len(hist)}")
print(f"Dataset size:      {sum([x[1] for x in hist])}")
print(f"Gini coefficient:  {gini([x[1] for x in hist])}")
# Out:
# Number of classes: 801
# Dataset size:      77628
# Gini coefficient:  0.9738106261386695

# %%
# Printing material, count, and percentage count of total
def printHist(hist):
    total = 0
    for row in hist:
        total += row[1]

    for row in hist:
        print(f"{row[0]}, {row[1]}, {(100 * row[1] / total):>0.1f}%")

printHist(hist)
# Out:
# prent, 52167, 67.2%
# tekening, 10882, 14.0%
# schilderij, 3271, 4.2%
# foto, 1768, 2.3%
# beeldhouwwerk, 538, 0.7%
# bord (vaatwerk), 519, 0.7%
# schotel, 491, 0.6%
# tekstblad, 488, 0.6%
# demonstratiemodel, 365, 0.5%
# kom, 337, 0.4%
# vaas, 283, 0.4%
# miniatuur, 274, 0.4%
# werfmodel, 238, 0.3%
# boek, 207, 0.3%
# schaal (objectnaam), 186, 0.2%
# historiepenning, 182, 0.2%
# vuursteenpistool, 180, 0.2%
# wijnglas, 136, 0.2%
# kan, 128, 0.2%
# beeld, 116, 0.1%
# kop, 115, 0.1%
# fles, 108, 0.1%
# carte-de-visite, 101, 0.1%
# kandelaar, 95, 0.1%
# pot, 94, 0.1%
# ruit, 94, 0.1%
# tsuba, 93, 0.1%
# wandtapijt, 91, 0.1%
# kop-en-schotel, 76, 0.1%
# doos, 72, 0.1%
# titelpagina, 67, 0.1%
# silhouet, 66, 0.1%
# plaat, 60, 0.1%
# figuur, 58, 0.1%
# instructiemodel, 52, 0.1%
# beker, 52, 0.1%
# kruik, 52, 0.1%
# plaquette, 48, 0.1%
# vouwwaaier, 48, 0.1%
# bokaal, 47, 0.1%
# theepot, 45, 0.1%
# tegel, 45, 0.1%
# zoutvat, 44, 0.1%
# inhoudsmaat droge waren, 42, 0.1%
# Indiase miniatuur, 40, 0.1%
# terrine, 40, 0.1%
# theebus, 35, 0.0%
# dekselpot, 33, 0.0%
# sleutel, 32, 0.0%
# snuifdoos, 32, 0.0%
# radslotpistool, 30, 0.0%
# percussiepistool, 30, 0.0%
# schildering, 29, 0.0%
# haarkam (haartooi), 29, 0.0%
# kozuka, 29, 0.0%
# presentatiemodel, 27, 0.0%
# botervloot, 27, 0.0%
# pronkmodel, 26, 0.0%
# netsuke, 26, 0.0%
# decoratief object, 26, 0.0%
# melkkan, 25, 0.0%
# deksel, 25, 0.0%
# kist, 24, 0.0%
# scheepsmodel, 24, 0.0%
# kruitmaat, 24, 0.0%
# kalligrafie, 24, 0.0%
# buste, 24, 0.0%
# stereofoto, 23, 0.0%
# degen, 22, 0.0%
# krant, 21, 0.0%
# roemer, 21, 0.0%
# sabel, 20, 0.0%
# noodmunt, 20, 0.0%
# slot, 20, 0.0%
# inro, 20, 0.0%
# ornamentprent, 19, 0.0%
# album, 19, 0.0%
# inhoudsmaat natte waren, 19, 0.0%
# lepel, 18, 0.0%
# albarello, 18, 0.0%
# wandelstok, 18, 0.0%
# beurs, 17, 0.0%
# monster (object), 17, 0.0%
# sauskom, 17, 0.0%
# knoop, 17, 0.0%
# speelbeurs, 17, 0.0%
# hanger (sieraad), 17, 0.0%
# gedicht, 16, 0.0%
# blad, 16, 0.0%
# orgelkast, 15, 0.0%
# borstelrug, 15, 0.0%
# inktstel, 15, 0.0%
# tas, 15, 0.0%
# kandelaber, 15, 0.0%
# rolschildering, 14, 0.0%
# kaart, 14, 0.0%
# bak, 14, 0.0%
# spiegel, 14, 0.0%
# suikerpot, 14, 0.0%
# graffiguur, 14, 0.0%
# reliëf, 13, 0.0%
# mand, 13, 0.0%
# gildepenning, 13, 0.0%
# brisé-waaier, 13, 0.0%
# draagteken, 13, 0.0%
# schoen, 12, 0.0%
# knip, 12, 0.0%
# kwispedoor, 12, 0.0%
# documentaire foto, 12, 0.0%
# servet, 12, 0.0%
# prentenalbum, 12, 0.0%
# vuursteenslot, 12, 0.0%
# prijspenning, 12, 0.0%
# damschijf, 12, 0.0%
# fluitglas, 11, 0.0%
# theelepel, 11, 0.0%
# brieventas, 11, 0.0%
# rekenpenning, 11, 0.0%
# kompas, 11, 0.0%
# toiletdoos, 11, 0.0%
# albumblad, 11, 0.0%
# glas (objectnaam), 11, 0.0%
# tabaksdoos, 11, 0.0%
# ring (sieraad), 11, 0.0%
# tabakspot, 11, 0.0%
# plaque, 11, 0.0%
# spoelkom, 10, 0.0%
# buidel, 10, 0.0%
# lilla, 10, 0.0%
# model, 10, 0.0%
# wijnkoeler, 10, 0.0%
# vork, 9, 0.0%
# tapijt, 9, 0.0%
# schild, 9, 0.0%
# fotoalbum, 9, 0.0%
# tafel, 9, 0.0%
# patentglas, 9, 0.0%
# kanon, 9, 0.0%
# erepenning, 9, 0.0%
# graanmaat, 9, 0.0%
# muts, 8, 0.0%
# vijzel, 8, 0.0%
# pistool, 8, 0.0%
# berkemeier, 8, 0.0%
# vleugelglas, 8, 0.0%
# kruithoorn, 8, 0.0%
# fragment, 8, 0.0%
# boekslot, 8, 0.0%
# theekop, 8, 0.0%
# pattipan, 8, 0.0%
# koffiekan, 8, 0.0%
# mosterdpot, 8, 0.0%
# komfoor, 8, 0.0%
# reticule, 8, 0.0%
# foedraal, 8, 0.0%
# schoengesp, 8, 0.0%
# olie- en azijnstel, 8, 0.0%
# applique, 8, 0.0%
# percussieslot, 8, 0.0%
# document, 8, 0.0%
# schenkkan, 8, 0.0%
# stoel, 7, 0.0%
# partizaan, 7, 0.0%
# granaat (munitie), 7, 0.0%
# mes (culinair gereedschap), 7, 0.0%
# knipselkunst, 7, 0.0%
# reliquiarium, 7, 0.0%
# tweehander, 7, 0.0%
# kroes, 7, 0.0%
# tafelmes, 7, 0.0%
# strooipenning, 7, 0.0%
# knobbelfles, 7, 0.0%
# schijf, 7, 0.0%
# vat, 7, 0.0%
# omslag, 7, 0.0%
# schilderijlijst, 7, 0.0%
# diorama, 6, 0.0%
# rolwagen, 6, 0.0%
# pamflet, 6, 0.0%
# oorkop, 6, 0.0%
# armstoel, 6, 0.0%
# fopkan, 6, 0.0%
# kast, 6, 0.0%
# musketvork, 6, 0.0%
# broche (sieraad), 6, 0.0%
# lint, 6, 0.0%
# tulpenhouder, 6, 0.0%
# tuinbeeld, 6, 0.0%
# trommel (houder), 6, 0.0%
# brief, 6, 0.0%
# doelgeweer, 6, 0.0%
# kraantjeskan, 6, 0.0%
# bekervaas, 6, 0.0%
# kroonluchter, 6, 0.0%
# titelprent, 6, 0.0%
# mal, 6, 0.0%
# scheerbekken, 6, 0.0%
# sierdegen, 6, 0.0%
# bierpul, 6, 0.0%
# kostuumprent, 6, 0.0%
# geweer, 6, 0.0%
# kastanjevaas, 6, 0.0%
# bril, 6, 0.0%
# inhoudsopgave, 6, 0.0%
# trom, 5, 0.0%
# penningdoos, 5, 0.0%
# melkmaat, 5, 0.0%
# cantonnière, 5, 0.0%
# oliemaat, 5, 0.0%
# dienblad, 5, 0.0%
# tafelbel, 5, 0.0%
# blaker, 5, 0.0%
# hellebaard, 5, 0.0%
# obelisk, 5, 0.0%
# tazza, 5, 0.0%
# tafelkleed, 5, 0.0%
# miskelk, 5, 0.0%
# vuursteengeweer, 5, 0.0%
# dieplood, 5, 0.0%
# punchkom, 5, 0.0%
# wierookbrander, 5, 0.0%
# stertegel, 5, 0.0%
# beulszwaard, 5, 0.0%
# kabinet, 5, 0.0%
# sierstuk, 5, 0.0%
# toverlantaarnplaat, 5, 0.0%
# haak, 4, 0.0%
# proefmodel, 4, 0.0%
# penning, 4, 0.0%
# console, 4, 0.0%
# bloemhouder, 4, 0.0%
# parasol, 4, 0.0%
# eresabel, 4, 0.0%
# scherf, 4, 0.0%
# krukgewicht, 4, 0.0%
# scherm, 4, 0.0%
# voorsnijmes, 4, 0.0%
# waterkan, 4, 0.0%
# stoof, 4, 0.0%
# kamerscherm, 4, 0.0%
# sokkel, 4, 0.0%
# sluitstuk, 4, 0.0%
# handschrift, 4, 0.0%
# onbekend, 4, 0.0%
# constructiemodel, 4, 0.0%
# munt, 4, 0.0%
# hamer, 4, 0.0%
# spotprent, 4, 0.0%
# kogel (munitie), 4, 0.0%
# wijnkan, 4, 0.0%
# pijpenslee, 4, 0.0%
# hartsvanger, 4, 0.0%
# tegeltableau, 4, 0.0%
# gordelhaak, 4, 0.0%
# masker, 4, 0.0%
# bekken (schaal), 4, 0.0%
# sluitgewicht, 4, 0.0%
# armband, 4, 0.0%
# zuil, 4, 0.0%
# medaillon (sieraad), 4, 0.0%
# theeservies, 4, 0.0%
# voetstuk, 4, 0.0%
# pul, 4, 0.0%
# nieuwsprent, 4, 0.0%
# handschrift (document), 4, 0.0%
# achterglasschildering, 4, 0.0%
# reukfles, 4, 0.0%
# nautilusbeker, 4, 0.0%
# gevelsteen, 3, 0.0%
# topografische tekening, 3, 0.0%
# roompot, 3, 0.0%
# vuurpot, 3, 0.0%
# etui, 3, 0.0%
# rozenwaterflacon, 3, 0.0%
# lamp, 3, 0.0%
# wijnbeker, 3, 0.0%
# wierookvat, 3, 0.0%
# dolk, 3, 0.0%
# chocoladekan, 3, 0.0%
# blok, 3, 0.0%
# strook, 3, 0.0%
# bajonet, 3, 0.0%
# baardmankruik, 3, 0.0%
# logvin, 3, 0.0%
# weegschaal, 3, 0.0%
# gouache, 3, 0.0%
# halfmodel, 3, 0.0%
# juwelenkist, 3, 0.0%
# kaststel, 3, 0.0%
# stamper, 3, 0.0%
# verklaring, 3, 0.0%
# cachepot, 3, 0.0%
# bloempot, 3, 0.0%
# kruittester, 3, 0.0%
# tuinvaas, 3, 0.0%
# knottedoos, 3, 0.0%
# mensenhaar, 3, 0.0%
# suzuribako, 3, 0.0%
# helm, 3, 0.0%
# bot, 3, 0.0%
# piek, 3, 0.0%
# commode, 3, 0.0%
# koffer, 3, 0.0%
# kendi, 3, 0.0%
# epaulet, 3, 0.0%
# dekselvaas, 3, 0.0%
# tondeldoos, 3, 0.0%
# bloempiramide, 3, 0.0%
# meetinstrument, 3, 0.0%
# prijspen, 3, 0.0%
# paneel, 3, 0.0%
# windinstrument, 3, 0.0%
# passer, 3, 0.0%
# urn, 3, 0.0%
# huwelijkspenning, 3, 0.0%
# haringschaal, 3, 0.0%
# maquette, 3, 0.0%
# zaksmaat, 3, 0.0%
# pelgrimsfles, 3, 0.0%
# vlag, 3, 0.0%
# brandewijnkom, 3, 0.0%
# jardinière, 3, 0.0%
# stokwapen, 3, 0.0%
# portretmedaillon, 3, 0.0%
# vochtweger, 3, 0.0%
# coupe, 3, 0.0%
# humpen, 3, 0.0%
# walbus, 3, 0.0%
# slakom, 3, 0.0%
# parfumbrander, 3, 0.0%
# broodmand, 3, 0.0%
# gordel, 3, 0.0%
# rapier, 3, 0.0%
# rammelaar, 3, 0.0%
# zijdeweefsel, 3, 0.0%
# secretaire, 3, 0.0%
# molenglas, 3, 0.0%
# rotting, 3, 0.0%
# drukwerk, 3, 0.0%
# waaier, 3, 0.0%
# penseelhouder, 3, 0.0%
# toiletkist, 2, 0.0%
# plattegrond, 2, 0.0%
# haar (materiaal), 2, 0.0%
# puntfles, 2, 0.0%
# steun, 2, 0.0%
# windwijzer, 2, 0.0%
# domper, 2, 0.0%
# wandelstokknop, 2, 0.0%
# begrafenispenning, 2, 0.0%
# reukbal, 2, 0.0%
# luifelhoed, 2, 0.0%
# klok, 2, 0.0%
# chrismatorium, 2, 0.0%
# scheepslantaarn, 2, 0.0%
# lepelvaas, 2, 0.0%
# voetenbank, 2, 0.0%
# stokknop, 2, 0.0%
# bel, 2, 0.0%
# offerblok, 2, 0.0%
# handschoen, 2, 0.0%
# afgietsel, 2, 0.0%
# bouwfragment, 2, 0.0%
# gildeschild, 2, 0.0%
# bouilloire, 2, 0.0%
# rijtuigparasol, 2, 0.0%
# historieprent, 2, 0.0%
# houtblok, 2, 0.0%
# hoed, 2, 0.0%
# vaandel, 2, 0.0%
# kastane, 2, 0.0%
# schoorsteenfries, 2, 0.0%
# theekist, 2, 0.0%
# scheepsvlag, 2, 0.0%
# scheepstuig, 2, 0.0%
# merklap, 2, 0.0%
# fruitmand, 2, 0.0%
# vogelkooi, 2, 0.0%
# zwaard (wapen), 2, 0.0%
# gewicht, 2, 0.0%
# lantaarn, 2, 0.0%
# rolpaard (vuurwapenonderdeel), 2, 0.0%
# flacon, 2, 0.0%
# dissel, 2, 0.0%
# sjaal, 2, 0.0%
# centraalvuurgeweer, 2, 0.0%
# rookstel, 2, 0.0%
# snuiter, 2, 0.0%
# sabelbajonet, 2, 0.0%
# landkaart, 2, 0.0%
# bal, 2, 0.0%
# monstrans, 2, 0.0%
# pyxide, 2, 0.0%
# deurknop, 2, 0.0%
# koker, 2, 0.0%
# poppenhuisgoed, 2, 0.0%
# perspectieftekening, 2, 0.0%
# tafelklok, 2, 0.0%
# boegbeeld, 2, 0.0%
# reaal, 2, 0.0%
# stalenboek, 2, 0.0%
# sliphaak, 2, 0.0%
# deurhengsel, 2, 0.0%
# lakpaneel, 2, 0.0%
# scepter, 2, 0.0%
# nimcha, 2, 0.0%
# wierookdoos, 2, 0.0%
# avondmaalskelk, 2, 0.0%
# gesp, 2, 0.0%
# ponjaard, 2, 0.0%
# manuscript, 2, 0.0%
# instrument, 2, 0.0%
# dwarsfluit, 2, 0.0%
# bekerschroef, 2, 0.0%
# notitieboek, 2, 0.0%
# zak, 2, 0.0%
# huisaltaar, 2, 0.0%
# bazuin, 2, 0.0%
# spaarpot, 2, 0.0%
# kussen, 2, 0.0%
# bladmuziek, 2, 0.0%
# radslotkarabijn, 2, 0.0%
# oesterschelp, 2, 0.0%
# zandstrooier, 2, 0.0%
# molenbeker, 2, 0.0%
# priem, 2, 0.0%
# haarkam, 2, 0.0%
# meter, 2, 0.0%
# lichtarm, 2, 0.0%
# waaierblad, 2, 0.0%
# ontwerptekening, 2, 0.0%
# peper- en zoutstel, 2, 0.0%
# theekom, 2, 0.0%
# hangrol, 2, 0.0%
# aquarel, 2, 0.0%
# palempore, 2, 0.0%
# gedenkteken, 2, 0.0%
# oosters tapijt, 2, 0.0%
# radslot, 2, 0.0%
# ketel, 2, 0.0%
# kachelplaat, 2, 0.0%
# priesterschel, 2, 0.0%
# hyacintenbak, 2, 0.0%
# kom op voet, 2, 0.0%
# maatstok, 2, 0.0%
# karaf, 2, 0.0%
# wandbespanning, 2, 0.0%
# stortebeker, 2, 0.0%
# schelp, 2, 0.0%
# lessenaar, 2, 0.0%
# patroonmal, 2, 0.0%
# drinkhoorn, 2, 0.0%
# monsterbord, 2, 0.0%
# oorhanger, 2, 0.0%
# wapenbord, 2, 0.0%
# sprei, 2, 0.0%
# sakefles, 2, 0.0%
# brochure, 2, 0.0%
# kokosnootbeker, 2, 0.0%
# fontein, 2, 0.0%
# notenkraker, 2, 0.0%
# touw, 2, 0.0%
# luiermand, 2, 0.0%
# pasglas, 2, 0.0%
# musket, 2, 0.0%
# clinometer, 2, 0.0%
# harpoen, 2, 0.0%
# zegel, 2, 0.0%
# specerijpot, 2, 0.0%
# Marianum, 2, 0.0%
# kapmes, 2, 0.0%
# sirihdoos, 2, 0.0%
# tafellaken, 2, 0.0%
# dobbelglas, 2, 0.0%
# tafelstuk, 2, 0.0%
# grafbord, 2, 0.0%
# lakdoos, 2, 0.0%
# kruistegel, 2, 0.0%
# messenheft, 2, 0.0%
# blaasbalg, 2, 0.0%
# bootmansfluit, 2, 0.0%
# beeldengroep, 2, 0.0%
# kom met deksel, 1, 0.0%
# trechter, 1, 0.0%
# speeldoos, 1, 0.0%
# altaarlessenaar, 1, 0.0%
# lambrekijn, 1, 0.0%
# schuier, 1, 0.0%
# waterpijp, 1, 0.0%
# pendulekast, 1, 0.0%
# trommelstok, 1, 0.0%
# balans (meetinstrument), 1, 0.0%
# borduurwerk, 1, 0.0%
# herenkleding, 1, 0.0%
# handboeien, 1, 0.0%
# vouwstoel, 1, 0.0%
# tête-à-tête, 1, 0.0%
# knobbelhoornbeker, 1, 0.0%
# psychrometer, 1, 0.0%
# spatscherm, 1, 0.0%
# boor, 1, 0.0%
# onderkast, 1, 0.0%
# kris, 1, 0.0%
# kraag, 1, 0.0%
# tweetoerenslot, 1, 0.0%
# nautilusschelp, 1, 0.0%
# bol, 1, 0.0%
# stempel, 1, 0.0%
# pijpenfoedraal, 1, 0.0%
# waterspuwer, 1, 0.0%
# pagode, 1, 0.0%
# po, 1, 0.0%
# ciborie, 1, 0.0%
# vijl, 1, 0.0%
# kakemono, 1, 0.0%
# lichtkaatser, 1, 0.0%
# handlood, 1, 0.0%
# lak, 1, 0.0%
# borstkruis, 1, 0.0%
# tafelhorloge, 1, 0.0%
# schuifsleutel, 1, 0.0%
# uurwerk, 1, 0.0%
# propagandaprent, 1, 0.0%
# oorring, 1, 0.0%
# viskom, 1, 0.0%
# pendule, 1, 0.0%
# uitgeversbrochure, 1, 0.0%
# veldfles, 1, 0.0%
# predella, 1, 0.0%
# overlijdenspenning, 1, 0.0%
# roerstok, 1, 0.0%
# drinkschaal, 1, 0.0%
# toilettafel, 1, 0.0%
# paraplu, 1, 0.0%
# preekstoel, 1, 0.0%
# stroopkan, 1, 0.0%
# ring, 1, 0.0%
# snaphaangeweer, 1, 0.0%
# uithangbord, 1, 0.0%
# schets, 1, 0.0%
# burijn (object), 1, 0.0%
# schuimspaan, 1, 0.0%
# inktpot, 1, 0.0%
# toegangskaart, 1, 0.0%
# predikbeurtenbord, 1, 0.0%
# vergiet, 1, 0.0%
# reclamebord, 1, 0.0%
# maliënkolder, 1, 0.0%
# cartografie, 1, 0.0%
# emmer, 1, 0.0%
# reddingsboei, 1, 0.0%
# sigarenkist, 1, 0.0%
# knipsel, 1, 0.0%
# tak, 1, 0.0%
# modello, 1, 0.0%
# anker (scheepsuitrusting), 1, 0.0%
# kartetskogel, 1, 0.0%
# troffel, 1, 0.0%
# trepaan, 1, 0.0%
# schaakstuk, 1, 0.0%
# wandbord, 1, 0.0%
# damesschoen, 1, 0.0%
# wijnkaraf, 1, 0.0%
# pasteipot, 1, 0.0%
# bourdalou, 1, 0.0%
# geuzenpenning, 1, 0.0%
# waldhoorn, 1, 0.0%
# heft, 1, 0.0%
# kaft, 1, 0.0%
# soepbord, 1, 0.0%
# boekband, 1, 0.0%
# ambtsketen, 1, 0.0%
# bijl (gereedschap), 1, 0.0%
# snaphaanslot, 1, 0.0%
# luchtdrukgeweer, 1, 0.0%
# tuitkan, 1, 0.0%
# onderzetter, 1, 0.0%
# strooilepel, 1, 0.0%
# gravureplaat, 1, 0.0%
# kruisbeeld, 1, 0.0%
# hoekkast, 1, 0.0%
# chaire, 1, 0.0%
# beugeltas, 1, 0.0%
# visvergiet, 1, 0.0%
# tabernakeldeur, 1, 0.0%
# bugel, 1, 0.0%
# jachthoorn, 1, 0.0%
# hangmat, 1, 0.0%
# Sinclairsabel, 1, 0.0%
# ladenkast, 1, 0.0%
# steen (objectnaam), 1, 0.0%
# fotomechanisch procedé, 1, 0.0%
# bestekfoedraal, 1, 0.0%
# boei, 1, 0.0%
# servies, 1, 0.0%
# azijnmaat, 1, 0.0%
# lunula, 1, 0.0%
# theeketel, 1, 0.0%
# wijzerplaat, 1, 0.0%
# boterpot, 1, 0.0%
# ruiterharnas, 1, 0.0%
# handenwarmer, 1, 0.0%
# gordelpendant, 1, 0.0%
# jatagan, 1, 0.0%
# mergboor, 1, 0.0%
# facsimile, 1, 0.0%
# dakversiering, 1, 0.0%
# wandtafel, 1, 0.0%
# ontwerp, 1, 0.0%
# gewei, 1, 0.0%
# lampetstel, 1, 0.0%
# lampetkan, 1, 0.0%
# mof, 1, 0.0%
# vuurbok, 1, 0.0%
# vuurplaat, 1, 0.0%
# draaiblok, 1, 0.0%
# botermaat, 1, 0.0%
# schoorsteenval, 1, 0.0%
# legitimatiepenning, 1, 0.0%
# testament (wilsbeschikking), 1, 0.0%
# spel, 1, 0.0%
# knipmes, 1, 0.0%
# graadstok, 1, 0.0%
# kunstkast, 1, 0.0%
# trektafel, 1, 0.0%
# tableau, 1, 0.0%
# zeilsteen, 1, 0.0%
# schouw, 1, 0.0%
# lood (gewicht), 1, 0.0%
# ceremoniestaf, 1, 0.0%
# rokophouder, 1, 0.0%
# stok, 1, 0.0%
# zeepbakje, 1, 0.0%
# penselenstandaard, 1, 0.0%
# tamboer-maître stok, 1, 0.0%
# leer, 1, 0.0%
# kalender, 1, 0.0%
# steengoed, 1, 0.0%
# chanoekalamp, 1, 0.0%
# handleiding, 1, 0.0%
# overval, 1, 0.0%
# automaat, 1, 0.0%
# trompet, 1, 0.0%
# pijpsleutel, 1, 0.0%
# percussiegeweer, 1, 0.0%
# veldbed, 1, 0.0%
# mondstuk, 1, 0.0%
# naaldenkoker, 1, 0.0%
# collage, 1, 0.0%
# gereedschap, 1, 0.0%
# kruisboog, 1, 0.0%
# cassette, 1, 0.0%
# propagandalint, 1, 0.0%
# loterijbrief, 1, 0.0%
# borstel, 1, 0.0%
# kalkbak, 1, 0.0%
# fichesdoos, 1, 0.0%
# kelk, 1, 0.0%
# percussiebuis, 1, 0.0%
# gevestwapen, 1, 0.0%
# getijroos, 1, 0.0%
# waskom, 1, 0.0%
# struisvogelei, 1, 0.0%
# kuttrolf, 1, 0.0%
# slagband, 1, 0.0%
# schoenlepel, 1, 0.0%
# knottekist, 1, 0.0%
# beslag, 1, 0.0%
# kookpot, 1, 0.0%
# kwadrant, 1, 0.0%
# horlogestandaard, 1, 0.0%
# schede, 1, 0.0%
# misthoorn, 1, 0.0%
# lichtscherm, 1, 0.0%
# scheepsbel, 1, 0.0%
# braadijzer, 1, 0.0%
# diamant, 1, 0.0%
# barometer, 1, 0.0%
# schip, 1, 0.0%
# pyrotechnisch wapen, 1, 0.0%
# votiefbeeld, 1, 0.0%
# voorplat, 1, 0.0%
# pruikenstandaard, 1, 0.0%
# onderscheiding, 1, 0.0%
# bord (informatie), 1, 0.0%
# apothekersfles, 1, 0.0%
# keten, 1, 0.0%
# pilaster, 1, 0.0%
# schilderijenstandaard, 1, 0.0%
# kamer, 1, 0.0%
# schaar, 1, 0.0%
# kinderstoel, 1, 0.0%
# kompasdoos, 1, 0.0%
# Jacobakan, 1, 0.0%
# dreg, 1, 0.0%
# Johannesschotel, 1, 0.0%
# rek, 1, 0.0%
# brievenbus, 1, 0.0%
# soepterrine, 1, 0.0%
# luizenkam, 1, 0.0%
# scheepssier, 1, 0.0%
# peper, 1, 0.0%
# Hansje-in-de-kelder, 1, 0.0%
# passant, 1, 0.0%
# avondmaalsschotel, 1, 0.0%
# scharnierbril, 1, 0.0%
# binnenbak, 1, 0.0%
# medaillon, 1, 0.0%
# kachel, 1, 0.0%
# revolver, 1, 0.0%
# staaf, 1, 0.0%
# schutterspenning, 1, 0.0%
# wapenrek, 1, 0.0%
# watervat, 1, 0.0%
# mitaine, 1, 0.0%
# stereofoto (tissue), 1, 0.0%
# lijkkleed, 1, 0.0%
# condensor, 1, 0.0%
# spanzaag, 1, 0.0%
# ijsemmer, 1, 0.0%
# hoekmeter, 1, 0.0%
# koffiefilterpot, 1, 0.0%
# aardappelmaat, 1, 0.0%
# doopkleed, 1, 0.0%
# duimenglas, 1, 0.0%
# brillenetui, 1, 0.0%
# patroontas, 1, 0.0%
# vlas, 1, 0.0%
# voetangel, 1, 0.0%
# lavabo, 1, 0.0%
# bierkan, 1, 0.0%
# schaakspel, 1, 0.0%
# kussenblad, 1, 0.0%
# bliksemafleider, 1, 0.0%
# drukletter, 1, 0.0%
# tegengewicht, 1, 0.0%
# kluister, 1, 0.0%
# gebedsnoot, 1, 0.0%
# sponton, 1, 0.0%
# scheepskompas, 1, 0.0%
# boekethouder, 1, 0.0%
# porseleinkast, 1, 0.0%
# plooischotel, 1, 0.0%
# koevoet, 1, 0.0%
# hyacintenvaas, 1, 0.0%
# sieraad, 1, 0.0%
# wijwaterbak, 1, 0.0%
# schinkelhaak, 1, 0.0%
# standaard (identificatiedrager), 1, 0.0%
# deurklopper, 1, 0.0%
# oorkonde, 1, 0.0%
# wierookschaal, 1, 0.0%
# schep, 1, 0.0%
# negatief, 1, 0.0%
# gebakschaal, 1, 0.0%
# toneelkijker, 1, 0.0%
# roncone, 1, 0.0%
# roer (voertuigonderdeel), 1, 0.0%
# paxtafel, 1, 0.0%
# zonnewijzer, 1, 0.0%
# broekgesp, 1, 0.0%
# necessaire, 1, 0.0%
# waterdruppelaar, 1, 0.0%
# musketkogel, 1, 0.0%
# haarkam (toiletartikel), 1, 0.0%
# bonbonmand, 1, 0.0%
# brillendoos, 1, 0.0%
# geldbuidel, 1, 0.0%
# grafvaas, 1, 0.0%
# slotplaat, 1, 0.0%
# garen, 1, 0.0%
# kandijbak, 1, 0.0%
# handvat, 1, 0.0%
# spreidloopwapen, 1, 0.0%
# lijstdeel, 1, 0.0%
# opzet, 1, 0.0%
# dop, 1, 0.0%
# waterbak, 1, 0.0%
# patroontekening, 1, 0.0%
# herinneringsobject, 1, 0.0%
# graftombe, 1, 0.0%
# suikerdoos, 1, 0.0%
# koffie- en theeservies, 1, 0.0%
# stoelbekleding, 1, 0.0%
# wapenschild, 1, 0.0%
# haarsieraad, 1, 0.0%
# rinkelbel, 1, 0.0%
# strooibus, 1, 0.0%
# schuif, 1, 0.0%
# hoorn (objectnaam), 1, 0.0%
# opzetstuk, 1, 0.0%
# steek, 1, 0.0%
# test, 1, 0.0%
# juwelenkoffer, 1, 0.0%
# makimono, 1, 0.0%
# handspiegel, 1, 0.0%
# kolder, 1, 0.0%
# scharnier, 1, 0.0%
# viool, 1, 0.0%
# zakdoek, 1, 0.0%
# mes (snijgereedschap), 1, 0.0%

# %%
# Creating a subset where there is a maximum to the number of instances per class.
# If a class has more than this maximum, an random sample is picked.
# Moreover, there is a maximum number of classes
max_instances = 1000
num_classes = 15

# Splitting the first 'num_classes' into a set of small enough ones and too big ones:
good_sized_classes = [row[0] for row in hist[:num_classes] if row[1] <= max_instances]
too_big_classes    = [row[0] for row in hist[:num_classes] if row[1] >  max_instances]

# Already adding all instances of 'good_sized_classes':
pairs_subset = [pair for pair in pairs if pair[1] in good_sized_classes]

# Adding 'max_instances' random samples of the too big classes:
for material in too_big_classes:
    all = [pair for pair in pairs if pair[1] == material]
    random.shuffle(all)
    pairs_subset += all[:max_instances]

# Finally, randomly shuffling the subset:
random.shuffle(pairs_subset)

# %%
hist_subset = createHist(pairs_subset)

print(f"Number of classes: {len(hist_subset)}")
print(f"Dataset size:      {sum([x[1] for x in hist_subset])}")
print(f"Gini coefficient:  {gini([x[1] for x in hist_subset])}")

print("\n------------------\n")

printHist(hist_subset)
# Out:
# Number of classes: 15
# Dataset size:      7926
# Gini coefficient:  0.3099503742955673
#
# ------------------
#
# tekening, 1000, 12.6%
# schilderij, 1000, 12.6%
# foto, 1000, 12.6%
# prent, 1000, 12.6%
# beeldhouwwerk, 538, 6.8%
# bord (vaatwerk), 519, 6.5%
# schotel, 491, 6.2%
# tekstblad, 488, 6.2%
# demonstratiemodel, 365, 4.6%
# kom, 337, 4.3%
# vaas, 283, 3.6%
# miniatuur, 274, 3.5%
# werfmodel, 238, 3.0%
# boek, 207, 2.6%
# schaal (objectnaam), 186, 2.3%

# %%
# Saving the new subset as a csv file:
subsetDf = pd.DataFrame.from_dict({
    "jpg":      [row[0] for row in pairs_subset],
    "material": [row[1] for row in pairs_subset]
})

subsetDf.to_csv("subset_data.csv", index=False)

# %%
# Saving the corresponding histogram as well:
subsetHistDf = pd.DataFrame.from_dict({
    "material": [row[0] for row in hist_subset],
    "count":    [row[1] for row in hist_subset]
})

subsetHistDf.to_csv("subset_hist_data.csv", index=False)
